# %%
import sys
import os
sys.path.insert(0, "C:/mnt/data")
from exseq_kit import SampleObject, ProjectObject
import numpy as np
# Load sample
samp_folder = r"C:\Users\Moshe\OneDrive\coding\SpatialGenomicsLab\SegmentedData\Organoids\test\001iSTXBP1_C3_top"
rna_file_format = "FOV1FOV_1.output.csv.withoutRF.csv.withCells.csv"
xy_scaling = 1/3.3 if "enlarge" in rna_file_format else 0.171/3.3
z_scaling = 1/3.3 if "enlarge" in rna_file_format else 0.4/3.3
samp_data = SampleObject.from_files(
    samp_folder, os.path.join(samp_folder, rna_file_format), xy_scaling=xy_scaling, z_scaling=z_scaling)
cells_file_format = r"FOV1FOV_1_round001_ch00.tif.cells.tif"
samp_data.load_cell_shapes_from_tif(
    os.path.join(samp_folder, cells_file_format), downsample=1, tif_xy_scaling=0.171/3.3, tif_z_scaling=0.4/3.3)

# %%
# # replace x with y in rna df for true displaying
# samp_data.RNA_loc_df['temp'] = samp_data.RNA_loc_df['X']
# samp_data.RNA_loc_df['X'] = samp_data.RNA_loc_df['Y']
# samp_data.RNA_loc_df['Y'] = samp_data.RNA_loc_df['temp']

# %%
random_ch = True
random_cell = np.random.choice(samp_data.cells.cell_id, 1) if random_ch else '880' # 10 good, 880 bad
print("cell num:", random_cell)
print("num of punctas:", np.sum(samp_data.RNA_loc_df.cell_id == random_cell[0]))
# print(samp_data.cell_voxels)
samp_data.plot_cell_with_puncta(cell_ids=random_cell)
# Out:
# cell num: ['1163']
# num of punctas: 5
# <div>                            <div id="31fb9442-b432-4d9c-afc9-1198dcc8832d" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31fb9442-b432-4d9c-afc9-1198dcc8832d")) {                    Plotly.newPlot(                        "31fb9442-b432-4d9c-afc9-1198dcc8832d",                        [{"color":"rgb(102,194,165)","i":[15,13,13,2,17,6,25,2,2,2,2,1,1,5,5,6,6,6,6,6,6,6,6,19,19,21,21,21,21,21,21,26,26,26,26,20,20,20,20,24,24,24,24,24,24,24,24,24,24,24],"j":[7,15,3,10,7,17,15,10,8,13,13,9,8,14,4,3,2,1,2,1,5,5,17,9,18,1,1,4,19,14,22,17,25,17,22,10,18,10,23,19,26,21,20,21,26,20,13,25,13,23],"k":[16,7,7,12,16,7,16,8,0,12,3,8,0,11,11,7,0,0,3,4,4,14,14,8,8,4,9,11,9,11,14,16,16,14,14,8,8,12,12,18,25,19,18,22,22,23,15,15,12,12],"name":"Cell 1163","opacity":0.2,"x":[94.93090909090911,95.76000000000002,93.68727272727274,93.68727272727274,97.41818181818184,97.41818181818184,96.58909090909093,95.76000000000002,94.93090909090911,95.34545454545456,92.85818181818183,97.83272727272728,92.44363636363637,92.44363636363637,97.83272727272728,94.10181818181819,95.34545454545456,95.76000000000002,94.10181818181819,96.17454545454547,92.85818181818183,97.83272727272728,97.83272727272728,92.44363636363637,92.44363636363637,93.27272727272728,95.76000000000002],"y":[50.574545454545465,50.574545454545465,51.81818181818183,52.23272727272728,52.23272727272728,54.720000000000006,55.549090909090914,55.96363636363637,50.16000000000001,50.16000000000001,52.23272727272728,52.647272727272735,53.476363636363644,54.30545454545455,54.30545454545455,55.96363636363637,56.37818181818183,56.37818181818183,50.98909090909092,50.98909090909092,52.23272727272728,52.647272727272735,53.06181818181819,53.476363636363644,54.30545454545455,55.13454545454546,55.13454545454546],"z":[52.363636363636374,52.363636363636374,52.363636363636374,52.363636363636374,52.363636363636374,52.363636363636374,52.363636363636374,52.363636363636374,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,53.33333333333334,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031,54.30303030303031],"type":"mesh3d"},{"marker":{"color":"rgb(102,194,165)","size":3},"mode":"markers","name":"CAMK2A (c=1163)","x":[96.70019555599005],"y":[52.04145764768346],"z":[53.791449906925706],"type":"scatter3d"},{"marker":{"color":"rgb(252,141,98)","size":3},"mode":"markers","name":"Kif5a (c=1163)","x":[93.00391971973774,92.99596773880646],"y":[54.189066443269425,54.18557297875932],"z":[54.12860052432801,54.426090657486675],"type":"scatter3d"},{"marker":{"color":"rgb(141,160,203)","size":3},"mode":"markers","name":"BSN (c=1163)","x":[95.92277667159007],"y":[51.05778300460694],"z":[54.622162850652245],"type":"scatter3d"},{"marker":{"color":"rgb(231,138,195)","size":3},"mode":"markers","name":"MOG (c=1163)","x":[93.46355160142335],"y":[52.9212591394373],"z":[55.18208872769649],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179 ...
